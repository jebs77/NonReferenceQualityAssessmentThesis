# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# non distorted soldier
df = pd.read_csv('CSV\soldier_param.csv')

figs, axs = plt.subplots(2, 2, figsize=(10, 10))
samples = np.arange(0, 300, 1)  # Define the range with your desired step size

axs[0,0].plot(samples, df['sphericity_mean'])
axs[0,1].plot(samples, df['sphericity_std'])
axs[1,0].plot(samples, df['sphericity_entropy'])
axs[1,1].plot(samples, df['sphericity_aggd4'])

# non distorted soldier
df1 = pd.read_csv('CSV\loot_param.csv')

figs1, axs1 = plt.subplots(2, 2, figsize=(10, 10))
samples1 = np.arange(0, 300, 1)  # Define the range with your desired step size

axs1[0,0].plot(samples1, df1['sphericity_mean'])
axs1[0,1].plot(samples1, df1['sphericity_std'])
axs1[1,0].plot(samples1, df1['sphericity_entropy'])
axs1[1,1].plot(samples1, df1['sphericity_aggd4'])
#distorted
df2 = pd.read_csv("completed_csv\house_distorted_model_parameters.csv")

figs2, axs2 = plt.subplots(2, 2, figsize=(10, 10))
samples = np.arange(0, 37, 1)  # Define the range with your desired step size

axs2[0,0].plot(samples, df2['sphericity_mean'])
axs2[0,1].plot(samples, df2['sphericity_std'])
axs2[1,0].plot(samples, df2['sphericity_entropy'])
axs2[1,1].plot(samples, df2['sphericity_aggd4'])
