# %%
import feature_extract as fe
import feature_functions as ff
from pyntcloud import PyntCloud
import time
import csv
import pandas as pd
import os
import glob
import pyntcloud

features = fe.get_feature_vector("VSENSE/Rafa2_ply_TMC2-randomAc_r5/Rafa2_ply_400K_ctc_r5_296.ply")
ff.print_info(features)
features.insert(0, "VSENSE/Rafa2_ply_TMC2-randomAc_r5/Rafa2_ply_400K_ctc_r5_296.ply")
ff.append_csv("test.csv", features)
# Out:
# Begin loading point cloud
# Begin geometry feature extraction.
# Begin color feature extraction.
# Begin NSS parameters estimation.
# l_mean: 37.13253608092665
# l_std: 18.153953983194093
# l_entropy: 6.772945366153691
# a_mean: -3.0029516593239567
# a_std: 4.809473037561801
# a_entropy: 5.976742501447789
# b_mean: 1.8857239824558305
# b_std: 6.923394453984677
# b_entropy: 6.638193239814425
# curvature_mean: 0.042306
# curvature_std: 0.028653048
# curvature_entropy: 5.351782353053609
# curvature_ggd1: 3.035
# curvature_ggd2: 0.051095914
# curvature_aggd1: 1.304
# curvature_aggd2: 0.35212542321522194
# curvature_aggd3: 0.7748508
# curvature_aggd4: 1.2449528
# curvature_gamma1: 2.1800346
# curvature_gamma2: 0.01940611
# anisotropy_mean: 0.92325777
# anisotropy_std: 0.055952974
# anisotropy_entropy: 5.16727804028154
# anisotropy_ggd1: 10.0
# anisotropy_ggd2: 0.9249516
# anisotropy_aggd1: 1.232
# anisotropy_aggd2: -0.44178873168521166
# anisotropy_aggd3: 1.3198439
# ...

# %%
cloud = PyntCloud.from_file("VSENSE/Rafa2_ply_TMC2-randomAc_r5/Rafa2_ply_400K_ctc_r5_296.ply")
cloud.points['x'] = -cloud.points['x']  # Flip horizontally along the x-axis

cloud.to_file("rafa_test_flipped.ply")

features = fe.get_feature_vector("rafa_test_flipped.ply")
ff.print_info(features)
features.insert(0, "rafa_test_flipped.ply")
ff.append_csv("test.csv", features)
# Out:
# d:\conda\envs\gpu_env\Lib\site-packages\pyntcloud\io\ply.py:260: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f = property_formats[str(df.dtypes[i])[0]]
# d:\conda\envs\gpu_env\Lib\site-packages\pyntcloud\io\ply.py:260: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f = property_formats[str(df.dtypes[i])[0]]
# d:\conda\envs\gpu_env\Lib\site-packages\pyntcloud\io\ply.py:260: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...
