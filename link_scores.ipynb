# %%
import pandas as pd
import numpy as np

vsense = pd.read_csv("CSV/vsense.csv")
scores = pd.read_csv("CSV/mos_std.csv")

print(len(scores))
print(len(vsense))
vsense["score"] = 0

vsense.head()
# Out:
# 64
# 19200
#                                                                                      name  \
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 52.083640 18.766955 4.202476  8.884968
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 51.243349 18.891353 4.220566  8.911762
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 52.168896 18.742579 4.188699  8.880102
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 51.291350 18.878524 4.181304  8.929318
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 51.361375 18.859589 4.187373  9.167459
#
#                                                                                  l_mean,l_std  \
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 52.083640 18.766955 4.202476      4.188308
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 51.243349 18.891353 4.220566      4.248117
# VSENSE\AxeGuy_ply_TMC1-raht_r1\AxeGuy_ply_400K_... 52.168896 18.742579 4.188699      4.053695
# ...

# %%
for i in range(len(scores)):
    for j in range(300):
        vsense["score"][i*300+j] = np.random.normal(scores["mos"][i], (scores["std"][i])/10)

vsense.head()

vsense.to_csv("with_score.csv")
# Out:
# C:\Users\jens7\AppData\Local\Temp\ipykernel_28572\1087659806.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   vsense["score"][i*300+j] = np.random.normal(scores["mos"][i], (scores["std"][i])/10)
